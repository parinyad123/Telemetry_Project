# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose

# Generate some data
np.random.seed(0)
n = 1500
dates = np.array('2005-01-01', dtype=np.datetime64) + np.arange(n)
data = 12*np.sin(2*np.pi*np.arange(n)/365) + np.random.normal(12, 2, 1500)
df = pd.DataFrame({'data': data}, index=dates)

# Reproduce the example in OP
seasonal_decompose(df, model='additive', freq=4).plot()
# Out:
# C:\Users\COM\Anaconda3\envs\timeSeries\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   del sys.path[0]

# %%
dates
# Out:
# array(['2005-01-01', '2005-01-02', '2005-01-03', ..., '2009-02-06',
#        '2009-02-07', '2009-02-08'], dtype='datetime64[D]')

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('airline-passengers.csv', header=0, index_col=0)
series.plot()
pyplot.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
series = read_csv('airline-passengers.csv', header=0, index_col=0)
result = seasonal_decompose(series, model='multiplicative',freq=8)
result.plot()
pyplot.show()
# Out:
# C:\Users\COM\Anaconda3\envs\timeSeries\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
series
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121
# ...             ...
# 1960-08         606
# 1960-09         508
# 1960-10         461
# 1960-11         390
# 1960-12         432
#
# [144 rows x 1 columns]

# %%
 result = seasonal_decompose(series, model='multiplicative')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-fc163c368797> in <module>
# ----> 1 result = seasonal_decompose(series, model='multiplicative')
#
# ~\Anaconda3\envs\timeSeries\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\Anaconda3\envs\timeSeries\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     140             period = pfreq
#     141         else:
# --> 142             raise ValueError("You must specify a period or x must be a "
#     143                              "pandas object with a DatetimeIndex with "
#     144                              "a freq not set to None")
#
# ValueError: You must specify a period or x must be a pandas object with a DatetimeIndex with a freq not set to None

# %%
series
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121
# ...             ...
# 1960-08         606
# 1960-09         508
# 1960-10         461
# 1960-11         390
# 1960-12         432
#
# [144 rows x 1 columns]

# %%
type(series)
# Out:
# pandas.core.frame.DataFrame

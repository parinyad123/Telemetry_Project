# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# C:\Users\COM\Anaconda3\envs\timeSeries\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
tickers=['AAPL']
start_date='2012-01-01'
end_date='2019-12-31'

#panel_data=data.DataReader('INPX','google',start_date,end_date)
panel_data = data.DataReader('INPX', 'yahoo', start_date, end_date)

# %%
panel_data
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2012-08-03  680400.000  680400.000  680400.000  680400.000        0.0
# 2012-08-06  680400.000  680400.000  680400.000  680400.000        0.0
# 2012-08-07  243000.000  243000.000  243000.000  243000.000        0.0
# 2012-08-08  243000.000  243000.000  243000.000  243000.000        0.0
# 2012-08-09  729000.000  729000.000  729000.000  729000.000        0.0
# ...                ...         ...         ...         ...        ...
# 2019-12-24       3.195       2.700       3.150       2.970   606600.0
# 2019-12-26       3.915       3.195       3.330       3.780  1657600.0
# 2019-12-27       3.870       3.420       3.690       3.510   810800.0
# 2019-12-30       3.825       3.375       3.645       3.420   854500.0
# 2019-12-31       5.625       4.320       5.220       4.905  4121700.0
#
#              Adj Close
# Date
# 2012-08-03  680400.000
# 2012-08-06  680400.000
# 2012-08-07  243000.000
# 2012-08-08  243000.000
# 2012-08-09  729000.000
# ...                ...
# 2019-12-24       2.970
# 2019-12-26       3.780
# 2019-12-27       3.510
# 2019-12-30       3.420
# 2019-12-31       4.905
#
# [1864 rows x 6 columns]

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web

style.use('ggplot')

start = dt.datetime(2015, 1, 1)
end = dt.datetime.now()
df = web.DataReader("TSLA", 'morningstar', start, end)
df.reset_index(inplace=True)
df.set_index("Date", inplace=True)
df = df.drop("Symbol", axis=1)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-4-e1a0fb6e8e9f> in <module>
#       9 start = dt.datetime(2015, 1, 1)
#      10 end = dt.datetime.now()
# ---> 11 df = web.DataReader("TSLA", 'morningstar', start, end)
#      12 df.reset_index(inplace=True)
#      13 df.set_index("Date", inplace=True)
#
# ~\Anaconda3\envs\timeSeries\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\Anaconda3\envs\timeSeries\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     374     if data_source not in expected_source:
#     375         msg = "data_source=%r is not implemented" % data_source
# --> 376         raise NotImplementedError(msg)
#     377
#     378     if data_source == "yahoo":
#
# NotImplementedError: data_source='morningstar' is not implemented

# %%
import pandas as pd
import pandas_datareader as dr
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

import math
import matplotlib.mlab as mlab

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df=dr.data.get_data_yahoo('ibm', start='2012-01-01', end='2019-12-31')
df.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2012-01-03  188.710007  186.000000  186.729996  186.300003  5646000.0
# 2012-01-04  186.330002  184.940002  185.570007  185.539993  4346700.0
# 2012-01-05  185.029999  183.100006  184.809998  184.660004  4463100.0
# 2012-01-06  184.479996  182.309998  184.389999  182.539993  4897100.0
# 2012-01-09  182.270004  180.270004  182.199997  181.589996  5201200.0
#
#              Adj Close
# Date
# 2012-01-03  139.934006
# 2012-01-04  139.363144
# 2012-01-05  138.702209
# 2012-01-06  137.109772
# 2012-01-09  136.396225

# %%
df.shape
# Out:
# (2012, 6)

# %%
df1=df
import numpy as np
df1['Temperature']=np.random.randint(25,80,size=(len(df1),1))
df2=df1[['Temperature']]
df2.head()
# Out:
#             Temperature
# Date
# 2012-01-03           31
# 2012-01-04           77
# 2012-01-05           45
# 2012-01-06           66
# 2012-01-09           69

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
series = read_csv('airline-passengers.csv', header=0, index_col=0)

# %%
print (series.to_csv(header=None,index=False))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-a3db88c9a68d> in <module>
# ----> 1 print (series.to_csv(header=None,index=False))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %%
import csv
import math
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import psycopg2
import pyramid
import random
import seaborn as sns
import statsmodels.tsa.stattools as ts
#from pyramid.arima import auto_arima
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose


from pandas import Series
from matplotlib import pyplot

# %%
series = np.log(series)

# %%
series
# Out:
# array([[1.23372204],
#        [1.46875079],
#        [1.33675282],
#        ...,
#        [1.44317233],
#        [1.25176463],
#        [1.27634526]])

# %%
series=df2.to_numpy()
series=np.log(series)
#series.plot()

# %%
decomposition=seasonal_decompose(df2, model='multiplicative')
# trend=decomposition.trend
# seasonal=decomposition.seasonal
# residual=decomposition.resid
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-4f2f0a92dbee> in <module>
# ----> 1 decomposition=seasonal_decompose(df2, model='multiplicative')
#       2 # trend=decomposition.trend
#       3 # seasonal=decomposition.seasonal
#       4 # residual=decomposition.resid
#
# ~\Anaconda3\envs\timeSeries\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\Anaconda3\envs\timeSeries\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     140             period = pfreq
#     141         else:
# --> 142             raise ValueError("You must specify a period or x must be a "
#     143                              "pandas object with a DatetimeIndex with "
#     144                              "a freq not set to None")
#
# ValueError: You must specify a period or x must be a pandas object with a DatetimeIndex with a freq not set to None

# %%
type(series)

# %%
plt.scatter(series, alpha=0.5)

# %%
series=df2.reset_index()
series.head()

# %%
df2.plot(kind='line',color='b',figsize=(20,5));

# %%
series

# %%
from pandas import Series
from matplotlib import pyplot
series.plot()
plt.xlabel('Year')
plt.ylabel('Maximum Temperature')
plt.title('Maximum Air Temperature in Dublin, Ireland')
pyplot.show()

# %%
decomposition=seasonal_decompose(series, model='multiplicative')

# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose

# Generate some data
np.random.seed(0)
n = 1500
dates = np.array('2005-01-01', dtype=np.datetime64) + np.arange(n)
data = 12*np.sin(2*np.pi*np.arange(n)/365) + np.random.normal(12, 2, 1500)
df = pd.DataFrame({'data': data}, index=dates)

# Reproduce the example in OP
seasonal_decompose(df, model='additive', freq=1).plot()
# Out:
# C:\Users\COM\Anaconda3\envs\timeSeries\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   del sys.path[0]

# %%
import csv
import math
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import psycopg2
import pyramid
import random
import seaborn as sns
import statsmodels.tsa.stattools as ts
from pyramid.arima import auto_arima
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose

import os;
path="directory"
os.chdir(path)
os.getcwd()

from pandas import Series
from matplotlib import pyplot
series = Series.from_csv('mly532.csv', header=0)
series = np.log(series)
series.plot()
plt.xlabel('Year')
plt.ylabel('Maximum Temperature')
plt.title('Maximum Air Temperature in Dublin, Ireland')
pyplot.show()

import statsmodels.api as sm  
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.seasonal import seasonal_decompose

train, test = series[1:741], series[742:927]
train.shape
test.shape
plt.plot(train)
plt.plot(test)
plt.title("Training and Test Data")
plt.show()

model=sm.tsa.statespace.SARIMAX(endog=train,order=(1,0,0),seasonal_order=(2,1,0,12),trend='c',enforce_invertibility=False)
results=model.fit()
print(results.summary())

predictions=results.predict(741, 925, typ='levels')
predictions=np.exp(predictions)
test=np.exp(test)
mse=(predictions-test)/test
mse=abs(mse)
below10=mse[mse < 0.10].count()
plt.hist(below10)
plt.show()

all=mse.count()
accuracy=below10/all
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-3bcdcc6bd8dd> in <module>
#      11 import seaborn as sns
#      12 import statsmodels.tsa.stattools as ts
# ---> 13 from pyramid.arima import auto_arima
#      14 from statsmodels.tsa.stattools import acf, pacf
#      15 from statsmodels.tsa.arima_model import ARIMA
#
# ModuleNotFoundError: No module named 'pyramid.arima'
